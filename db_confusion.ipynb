# %%
from databroker import catalog

list(catalog['csx'])
# Out:
# OBJECT CACHE: Will use up to 121_695_745_228 bytes (15% of total physical RAM)
# ---------------------------------------------------------------------------
# WouldBlock                                Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/anyio/streams/memory.py in receive(self)
#      80         try:
# ---> 81             return self.receive_nowait()
#      82         except WouldBlock:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/anyio/streams/memory.py in receive_nowait(self)
#      75
# ---> 76         raise WouldBlock
#      77
#
# WouldBlock:
#
# During handling of the above exception, another exception occurred:
#
# EndOfStream                               Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/starlette/middleware/base.py in call_next(request)
#      40             try:
# ---> 41                 message = await recv_stream.receive()
# ...

# %%
list(catalog['chx'])
# Out:
# OBJECT CACHE: Will use up to 121_695_745_228 bytes (15% of total physical RAM)
