# %%
from databroker import catalog

list(catalog['csx'])
# Out:
# OBJECT CACHE: Will use up to 121_695_745_228 bytes (15% of total physical RAM)
# ---------------------------------------------------------------------------
# WouldBlock                                Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/anyio/streams/memory.py in receive(self)
#      80         try:
# ---> 81             return self.receive_nowait()
#      82         except WouldBlock:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/anyio/streams/memory.py in receive_nowait(self)
#      75
# ---> 76         raise WouldBlock
#      77
#
# WouldBlock:
#
# During handling of the above exception, another exception occurred:
#
# EndOfStream                               Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/starlette/middleware/base.py in call_next(request)
#      40             try:
# ---> 41                 message = await recv_stream.receive()
# ...

# %%
list(catalog['chx'])
# Out:
# OBJECT CACHE: Will use up to 121_695_745_228 bytes (15% of total physical RAM)
# ['cdf2aa32-d248-41a9-b714-5d572e5d1dd3',
#  '7109785a-ff3d-4e0e-81ad-de257284d1f0',
#  '0da90e55-770b-41e4-b9ca-cb40d95276de',
#  '293f4e49-65e9-45b6-a644-f674525aaf56',
#  'ffb0c15c-dcba-4214-a007-bcee13c9da1d',
#  'e42da4bf-a49b-4b8a-99a5-ac4c1d781e95',
#  'fc4c5a15-a1a2-4b8b-b006-600c26488b36',
#  'f3fa2a6d-acee-42c5-9f73-58d14344eefd',
#  'dc936dd8-5008-46b7-9e40-de6c2a4b29b9',
#  'd5969d75-d31b-4377-9be0-6930d4ad83c2',
#  'dbcec5c5-9d5d-46e5-afe1-da2267d39d7a',
#  '1ddec21d-c6ee-4404-b0cd-6e1601095592',
#  '755b04ab-4954-4757-8dd0-b7c8fb8c5d72',
#  'e8c82d5d-1f6d-4bf4-9d45-a7e200035590',
#  '489b655b-31bc-4739-9f2b-dc5ed59c147b',
#  'dda1a6a4-0a8c-4c85-b89a-18ae1cbc1e77',
#  'd5742305-bd26-4ee8-aec4-28014d5400bc',
#  '0e68409f-e7b9-46ac-beec-8ceab3a10c81',
#  'd5838e85-e353-4a89-bf08-8eaf637743e4',
#  'c407bf5e-948d-4d73-95a6-ff9c91e65f7c',
#  'bdea14f5-34c8-4f53-8d2a-788d1aae10f0',
# ...
